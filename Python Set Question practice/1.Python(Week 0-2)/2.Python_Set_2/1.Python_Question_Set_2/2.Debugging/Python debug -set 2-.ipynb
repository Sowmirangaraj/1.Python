# %%
#1.Find the error in the following Python code:
import math
print(Math.sqrt(16))

# %%
#1. Fixed code: Math should be lowercase
import math
print(math.sqrt(16))
# Out:
# 4.0

# %%
#2.Find the error in the following Python code:
def my_function():
    x += 5
    print(x)

x = 10
my_function()

# %%
#2.Fixed Code:

def my_function():
    global x
    x += 5
    print(x)

x = 10
my_function()
# Out:
# 15

# %%
#3.x = 5
if x = 10:
    print("x is 10")

# %%
#3. Fixed code:= is an assignment operator; == is needed for comparison.
x = 5
if x == 10:
    print("x is 10")

# %%
#4.
numbers = [5, 3, 8, 2]
print(numbers.sort())

# %%
#4. Fixed code:
numbers = [5, 3, 8, 2]
numbers.sort()
print(numbers)
# Out:
# [2, 3, 5, 8]

# %%
#5.
def square(n):
    n * n

print(square(4))

# %%
#5.Fixed code:
def square(n):
     return n * n

print(square(4))
# Out:
# 16

# %%
#6.
my_tuple = (1, 2, 3)
my_tuple[1] = 5

# %%
#6.Fixed code:Tuples are immutable and cannot be modified.

my_tuple = (1, 5, 3) # Create a new tuple

# %%
#7.
name = "Alice"
age = 25
print("My name is %s and I am %d years old" % (name))

# %%
#7.Fixed code:
name = "Alice"
age = 25
print("My name is %s and I am %d years old" % (name,age))
# Out:
# My name is Alice and I am 25 years old

# %%
#8.
a = [1, 2, 3]
b = [1, 2, 3]
if a is b:
    print("Lists are equal")

# %%
#8. Fixed code:
a = [1, 2, 3]
b = [1, 2, 3]
if a == b:
    print("Lists are equal")
# Out:
# Lists are equal

# %%
#9.
for i in range(5, 1):
    print(i)

# %%
#9. Fixed code: The range(5, 1) does not produce any numbers because the default step is +1.
for i in range(5, 1,-1):
    print(i)
# Out:
# 5
# 4
# 3
# 2

# %%
#10.
student = {"name": "John", "age": 20}
print(student[name])

# %%
#10. Fixed code:
student = {"name": "John", "age": 20}
print(student["name"])
# Out:
# John
